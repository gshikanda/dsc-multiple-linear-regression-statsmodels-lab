# %% [markdown]
# # Multiple Linear Regression in Statsmodels - Lab

# %% [markdown]
# ## Introduction
# In this lab, you'll practice fitting a multiple linear regression model on the Ames Housing dataset!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Determine if it is necessary to perform normalization/standardization for a specific model or set of data
# * Use standardization/normalization on features of a dataset
# * Identify if it is necessary to perform log transformations on a set of features
# * Perform log transformations on different features of a dataset
# * Use statsmodels to fit a multiple linear regression model
# * Evaluate a linear regression model by using statistical performance metrics pertaining to overall model and specific parameters

# %% [markdown]
# ## The Ames Housing Data

# %% [markdown]
# Using the specified continuous and categorical features, preprocess your data to prepare for modeling:
# * Split off and one hot encode the categorical features of interest
# * Log and scale the selected continuous features

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

ames = pd.read_csv('ames.csv')

continuous = ['LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']
categoricals = ['BldgType', 'KitchenQual', 'SaleType', 'MSZoning', 'Street', 'Neighborhood']

# %%
df=pd.DataFrame(ames)
df[categoricals]
# Out:
#      BldgType KitchenQual SaleType MSZoning Street Neighborhood
# 0        1Fam          Gd       WD       RL   Pave      CollgCr
# 1        1Fam          TA       WD       RL   Pave      Veenker
# 2        1Fam          Gd       WD       RL   Pave      CollgCr
# 3        1Fam          Gd       WD       RL   Pave      Crawfor
# 4        1Fam          Gd       WD       RL   Pave      NoRidge
# ...       ...         ...      ...      ...    ...          ...
# 1455     1Fam          TA       WD       RL   Pave      Gilbert
# 1456     1Fam          TA       WD       RL   Pave       NWAmes
# 1457     1Fam          Gd       WD       RL   Pave      Crawfor
# 1458     1Fam          Gd       WD       RL   Pave        NAmes
# 1459     1Fam          TA       WD       RL   Pave      Edwards
#
# [1460 rows x 6 columns]

# %% [markdown]
# ## Continuous Features

# %%
# Log transform and normalize
df=pd.DataFrame(ames)
df_continuous_log= df[continuous].apply(np.log1p)
scaler=StandardScaler()
df_continuous_scaler= scaler.fit_transform(df_continuous_log)
print(df_continuous_scaler)
# Out:
# [[-0.13327022 -0.80364504  0.52919393  0.56006699]
#  [ 0.11341289  0.41847858 -0.38196548  0.21276333]
#  [ 0.42004913 -0.57667677  0.65963119  0.73404616]
#  ...
#  [-0.00235902  0.22820766  1.47010236  1.17470887]
#  [ 0.13683278 -0.07772073 -0.8545358  -0.39965728]
#  [ 0.18011644  0.40347203 -0.39625742 -0.30669507]]

# %% [markdown]
# ## Categorical Features

# %%
# One hot encode categoricals
df[categoricals] = df[categoricals].astype('category')
df_encoded = pd.get_dummies(df,columns = categoricals, drop_first=True)
print(df_encoded)
# Out:
#         Id  MSSubClass  LotFrontage  LotArea Alley LotShape LandContour  \
# 0        1          60         65.0     8450   NaN      Reg         Lvl
# 1        2          20         80.0     9600   NaN      Reg         Lvl
# 2        3          60         68.0    11250   NaN      IR1         Lvl
# 3        4          70         60.0     9550   NaN      IR1         Lvl
# 4        5          60         84.0    14260   NaN      IR1         Lvl
# ...    ...         ...          ...      ...   ...      ...         ...
# 1455  1456          60         62.0     7917   NaN      Reg         Lvl
# 1456  1457          20         85.0    13175   NaN      Reg         Lvl
# 1457  1458          70         66.0     9042   NaN      Reg         Lvl
# 1458  1459          20         68.0     9717   NaN      Reg         Lvl
# 1459  1460          20         75.0     9937   NaN      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... Neighborhood_NoRidge  \
# 0       AllPub    Inside       Gtl  ...                    0
# 1       AllPub       FR2       Gtl  ...                    0
# 2       AllPub    Inside       Gtl  ...                    0
# 3       AllPub    Corner       Gtl  ...                    0
# 4       AllPub       FR2       Gtl  ...                    1
# ...        ...       ...       ...  ...                  ...
# 1455    AllPub    Inside       Gtl  ...                    0
# 1456    AllPub    Inside       Gtl  ...                    0
# 1457    AllPub    Inside       Gtl  ...                    0
# 1458    AllPub    Inside       Gtl  ...                    0
# 1459    AllPub    Inside       Gtl  ...                    0
#
#      Neighborhood_NridgHt Neighborhood_OldTown  Neighborhood_SWISU  \
# 0                       0                    0                   0
# 1                       0                    0                   0
# 2                       0                    0                   0
# 3                       0                    0                   0
# 4                       0                    0                   0
# ...                   ...                  ...                 ...
# 1455                    0                    0                   0
# 1456                    0                    0                   0
# 1457                    0                    0                   0
# 1458                    0                    0                   0
# 1459                    0                    0                   0
#
#       Neighborhood_Sawyer  Neighborhood_SawyerW  Neighborhood_Somerst  \
# 0                       0                     0                     0
# 1                       0                     0                     0
# 2                       0                     0                     0
# 3                       0                     0                     0
# 4                       0                     0                     0
# ...                   ...                   ...                   ...
# 1455                    0                     0                     0
# 1456                    0                     0                     0
# 1457                    0                     0                     0
# 1458                    0                     0                     0
# 1459                    0                     0                     0
#
#      Neighborhood_StoneBr Neighborhood_Timber Neighborhood_Veenker
# 0                       0                   0                    0
# 1                       0                   0                    1
# 2                       0                   0                    0
# 3                       0                   0                    0
# 4                       0                   0                    0
# ...                   ...                 ...                  ...
# 1455                    0                   0                    0
# 1456                    0                   0                    0
# 1457                    0                   0                    0
# 1458                    0                   0                    0
# 1459                    0                   0                    0
#
# [1460 rows x 119 columns]

# %% [markdown]
# ## Combine Categorical and Continuous Features

# %%
# combine features into a single dataframe called preprocessed
df_preprocessed = pd.concat([df_encoded,df_continuous_scaler],axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a3cbe9300afd> in <module>
#       1 # combine features into a single dataframe called preprocessed
# ----> 2 df_preprocessed = pd.concat([df_encoded,df_continuous_scaler],axis=1)
#
# c:\Users\user\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# c:\Users\user\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     357                     "only Series and DataFrame objs are valid"
#     358                 )
# --> 359                 raise TypeError(msg)
#     360
#     361             # consolidate
#
# TypeError: cannot concatenate object of type '<class 'numpy.ndarray'>'; only Series and DataFrame objs are valid

# %% [markdown]
# ## Run a linear model with SalePrice as the target variable in statsmodels

# %%
# Your code here

# %% [markdown]
# ## Run the same model in scikit-learn

# %%
# Your code here - Check that the coefficients and intercept are the same as those from Statsmodels

# %% [markdown]
# ## Predict the house price given the following characteristics (before manipulation!!)
#
# Make sure to transform your variables as needed!
#
# - LotArea: 14977
# - 1stFlrSF: 1976
# - GrLivArea: 1976
# - BldgType: 1Fam
# - KitchenQual: Gd
# - SaleType: New
# - MSZoning: RL
# - Street: Pave
# - Neighborhood: NridgHt

# %%
# Your code here - predict the house price given the following characteristics

# %% [markdown]
# ## Summary
# Congratulations! You pre-processed the Ames Housing data using scaling and standardization. You also fitted your first multiple linear regression model on the Ames Housing data using statsmodels and scikit-learn!
